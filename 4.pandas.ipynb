# %%
import pandas as pd
df=pd.read_csv('C:/Users/Suhit/Desktop/ML/ML course Applied/examples/nyc_weather.csv')
df
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
#get the maximum temperature
df['Temperature'].max()
# Out:
# 50

# %%
#to know which day it rains
df['EST'][df['Events'] == 'Rain']
# Out:
# 8      1/9/2016
# 9     1/10/2016
# 15    1/16/2016
# 26    1/27/2016
# Name: EST, dtype: object

# %%
#average wind speed
df['WindSpeedMPH'].mean()
# Out:
# 6.892857142857143

# %% [markdown]
# ## introduction to pandas dataframe

# %%
df=pd.read_csv('C:/Users/Suhit/Desktop/ML/ML course Applied/examples/weather_data.csv')   #read weather.csv data

df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017       -99999          7  Sunny
# 2  1/3/2017           28     -99999   Snow
# 3  1/4/2017       -99999          7      0
# 4  1/5/2017           32     -99999   Rain
# 5  1/6/2017           31          2  Sunny
# 6  1/6/2017           34          5      0

# %%
# we can create the same data by the list of tuples as follows,

weather_data=[('1/1/2017',32,6,'Rain'),
('1/2/2017',-99999,7,'Sunny'),
('1/3/2017',28,-99999,'Snow'),
('1/4/2017',-99999,7,'0'),
('1/5/2017',32,-99999,'Rain'),
('1/6/2017',31,2,'Sunny'),
('1/6/2017',34,5,'0')]

df=pd.DataFrame(weather_data,columns=['day','temperature','windspeed','events'])
df
# Out:
#         day  temperature  windspeed events
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017       -99999          7  Sunny
# 2  1/3/2017           28     -99999   Snow
# 3  1/4/2017       -99999          7      0
# 4  1/5/2017           32     -99999   Rain
# 5  1/6/2017           31          2  Sunny
# 6  1/6/2017           34          5      0

# %%
#get dimension of the table

df.shape  #total no. of rows and columns
# Out:
# (7, 4)

# %%
#if you want to see initial some rows then use head command(default 5 rows) will be visible

df.head()
# Out:
#         day  temperature  windspeed events
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017       -99999          7  Sunny
# 2  1/3/2017           28     -99999   Snow
# 3  1/4/2017       -99999          7      0
# 4  1/5/2017           32     -99999   Rain

# %%
#slicing
df[2:5]
# Out:
#         day  temperature  windspeed events
# 2  1/3/2017           28     -99999   Snow
# 3  1/4/2017       -99999          7      0
# 4  1/5/2017           32     -99999   Rain

# %%
df.columns  #print columns in a table
# Out:
# Index(['day', 'temperature', 'windspeed', 'events'], dtype='object')

# %%
df.day  #print particular column data
# Out:
# 0    1/1/2017
# 1    1/2/2017
# 2    1/3/2017
# 3    1/4/2017
# 4    1/5/2017
# 5    1/6/2017
# 6    1/6/2017
# Name: day, dtype: object

# %%
#another way of accesing column
df['day']  #df.day(both are same)
# Out:
# 0    1/1/2017
# 1    1/2/2017
# 2    1/3/2017
# 3    1/4/2017
# 4    1/5/2017
# 5    1/6/2017
# 6    1/6/2017
# Name: day, dtype: object

# %%
#get 2 or more columns
df[['day','events']]
# Out:
#         day events
# 0  1/1/2017   Rain
# 1  1/2/2017  Sunny
# 2  1/3/2017   Snow
# 3  1/4/2017      0
# 4  1/5/2017   Rain
# 5  1/6/2017  Sunny
# 6  1/6/2017      0

# %%
#get all temperatures
df['temperature']
# Out:
# 0       32
# 1   -99999
# 2       28
# 3   -99999
# 4       32
# 5       31
# 6       34
# Name: temperature, dtype: int64

# %%
#print max temperature
df['temperature'].max()
# Out:
# 34

# %%
#print min temperature
df['temperature'].min()
# Out:
# -99999

# %%
df['temperature'].describe()
# Out:
# count        7.000000
# mean    -28548.714286
# std      48809.837361
# min     -99999.000000
# 25%     -49985.500000
# 50%         31.000000
# 75%         32.000000
# max         34.000000
# Name: temperature, dtype: float64

# %%
# select rows which has maximum temperature
df[df.temperature == df.temperature.max()]
# Out:
#         day  temperature  windspeed events
# 6  1/6/2017           34          5      0

# %%
#select only day column which has maximum temperature
df.day[df.temperature == df.temperature.max()]
# Out:
# 6    1/6/2017
# Name: day, dtype: object

# %% [markdown]
# ## read and write csv and xls files

# %%
import pandas as pd
df=pd.read_csv('C:/Users/Suhit/Desktop/ML/ML course Applied/examples/weather_data.csv')  #csv= comma seperated values
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017       -99999          7  Sunny
# 2  1/3/2017           28     -99999   Snow
# 3  1/4/2017       -99999          7      0
# 4  1/5/2017           32     -99999   Rain
# 5  1/6/2017           31          2  Sunny
# 6  1/6/2017           34          5      0

# %%
#read excel file
df=pd.read_excel('C:/Users/Suhit/Desktop/ML/ML course Applied/examples/weather_data.xlsx')
df
# Out:
#          day  temperature  windspeed  event
# 0 2017-01-01           32          6   Rain
# 1 2017-01-02           35          7  Sunny
# 2 2017-01-03           28          2   Snow

# %%
#write DF to csv
df.to_csv('new.csv')
df.to_csv('new_noIndex.csv',index=False) # no index in this file if index=false.

# %%
#write Df to Excel
df.to_excel('new1.xlsx',sheet_name='weather_data_1')

# %% [markdown]
# ## group by

# %%
df=pd.read_csv('C:/Users/Suhit/Desktop/ML/ML course Applied/examples/weather_data_cities.csv')
df
# Out:
#         date      city  temperature  windspeed   event
# 0   1/1/2017  new york           32          6    Rain
# 1   1/2/2017  new york           36          7   Sunny
# 2   1/3/2017  new york           28         12    Snow
# 3   1/4/2017  new york           33          7   Sunny
# 4   1/1/2017    mumbai           90          5   Sunny
# 5   1/2/2017    mumbai           85         12     Fog
# 6   1/3/2017    mumbai           87         15     Fog
# 7   1/4/2017    mumbai           92          5    Rain
# 8   1/1/2017     paris           45         20   Sunny
# 9   1/2/2017     paris           50         13  Cloudy
# 10  1/3/2017     paris           54          8  Cloudy
# 11  1/4/2017     paris           42         10  Cloudy

# %%
g=df.groupby('city')
g

# %%
for city,city_df in g:
    print(city)
    print(city_df)
# Out:
# mumbai
#        date    city  temperature  windspeed  event
# 4  1/1/2017  mumbai           90          5  Sunny
# 5  1/2/2017  mumbai           85         12    Fog
# 6  1/3/2017  mumbai           87         15    Fog
# 7  1/4/2017  mumbai           92          5   Rain
# new york
#        date      city  temperature  windspeed  event
# 0  1/1/2017  new york           32          6   Rain
# 1  1/2/2017  new york           36          7  Sunny
# 2  1/3/2017  new york           28         12   Snow
# 3  1/4/2017  new york           33          7  Sunny
# paris
#         date   city  temperature  windspeed   event
# 8   1/1/2017  paris           45         20   Sunny
# 9   1/2/2017  paris           50         13  Cloudy
# 10  1/3/2017  paris           54          8  Cloudy
# 11  1/4/2017  paris           42         10  Cloudy

# %%
#or to get specific group
g.get_group('new york')
# Out:
#        date      city  temperature  windspeed  event
# 0  1/1/2017  new york           32          6   Rain
# 1  1/2/2017  new york           36          7  Sunny
# 2  1/3/2017  new york           28         12   Snow
# 3  1/4/2017  new york           33          7  Sunny

# %%
#find maximum temperature in each of the cities
print(g.max())
# Out:
#               date  temperature  windspeed  event
# city
# mumbai    1/4/2017           92         15  Sunny
# new york  1/4/2017           36         12  Sunny
# paris     1/4/2017           54         20  Sunny

# %%
print(g.mean())
# Out:
#           temperature  windspeed
# city
# mumbai          88.50       9.25
# new york        32.25       8.00
# paris           47.75      12.75

# %%
print(g.describe())
# Out:
#          temperature                                                   \
#                count   mean       std   min    25%   50%    75%   max
# city
# mumbai           4.0  88.50  3.109126  85.0  86.50  88.5  90.50  92.0
# new york         4.0  32.25  3.304038  28.0  31.00  32.5  33.75  36.0
# paris            4.0  47.75  5.315073  42.0  44.25  47.5  51.00  54.0
#
#          windspeed
#              count   mean       std  min   25%   50%    75%   max
# city
# mumbai         4.0   9.25  5.057997  5.0  5.00   8.5  12.75  15.0
# new york       4.0   8.00  2.708013  6.0  6.75   7.0   8.25  12.0
# paris          4.0  12.75  5.251984  8.0  9.50  11.5  14.75  20.0

# %% [markdown]
# ## concatenate data frames

# %%
import pandas as pd
indian_weather=pd.DataFrame({
    "city":["mumbai","delhi","banglore"],
    "temperature":[32,45,30],
    "humidity":[80,60,78]
})

indian_weather
# Out:
#        city  temperature  humidity
# 0    mumbai           32        80
# 1     delhi           45        60
# 2  banglore           30        78

# %%
us_weather=pd.DataFrame({
    "city":["new york","chicago","orlando"],
    "temperature":[21,14,35],
    "humidity":[68,65,75]
})

us_weather
# Out:
#        city  temperature  humidity
# 0  new york           21        68
# 1   chicago           14        65
# 2   orlando           35        75

# %%
#concate two dataframes
df=pd.concat([indian_weather,us_weather])
df
# Out:
#        city  temperature  humidity
# 0    mumbai           32        80
# 1     delhi           45        60
# 2  banglore           30        78
# 0  new york           21        68
# 1   chicago           14        65
# 2   orlando           35        75

# %%
#if you want continuos index
df=pd.concat([indian_weather,us_weather],ignore_index=True)
df
# Out:
#        city  temperature  humidity
# 0    mumbai           32        80
# 1     delhi           45        60
# 2  banglore           30        78
# 3  new york           21        68
# 4   chicago           14        65
# 5   orlando           35        75

# %%
df=pd.concat([indian_weather,us_weather],axis=1)
df
# Out:
#        city  temperature  humidity      city  temperature  humidity
# 0    mumbai           32        80  new york           21        68
# 1     delhi           45        60   chicago           14        65
# 2  banglore           30        78   orlando           35        75

# %% [markdown]
# ## merge dataframes

# %%
temperature_df=pd.DataFrame({
    "city":["mumbai","delhi","banglore","hyderabad"],
    "temperature":[32,45,30,40]
})

temperature_df
# Out:
#         city  temperature
# 0     mumbai           32
# 1      delhi           45
# 2   banglore           30
# 3  hyderabad           40

# %%
humidity_df=pd.DataFrame({
    "city":["delhi","mumbai","banglore"],
    "humidity":[68,65,75]
})

humidity_df
# Out:
#        city  humidity
# 0     delhi        68
# 1    mumbai        65
# 2  banglore        75

# %%
#merge two dataframes without explicitly mention index

df=pd.merge(temperature_df,humidity_df,on='city')
df
# Out:
#        city  temperature  humidity
# 0    mumbai           32        65
# 1     delhi           45        68
# 2  banglore           30        75

# %%
# outer-join
df=pd.merge(temperature_df,humidity_df,on='city',how='outer')
df
# Out:
#         city  temperature  humidity
# 0     mumbai           32      65.0
# 1      delhi           45      68.0
# 2   banglore           30      75.0
# 3  hyderabad           40       NaN

# %% [markdown]
# ## numaric indexing(.loc vs iloc)

# %%
df=pd.DataFrame([1,2,3,4,5,6,7,8,9,19], index=[49,48,47,46,45,1,2,3,4,5])

df
# Out:
#      0
# 49   1
# 48   2
# 47   3
# 46   4
# 45   5
# 1    6
# 2    7
# 3    8
# 4    9
# 5   19

# %%
df.loc[2]  #loc=location  ,it uses index values i.e @ index[2]=7
# Out:
# 0    7
# Name: 2, dtype: int64

# %%
df.iloc[3]  #iloc=index location   ,it uses row value i.e @ row[3]=4
# Out:
# 0    4
# Name: 46, dtype: int64

# %%
df.loc[:2]
# Out:
#     0
# 49  1
# 48  2
# 47  3
# 46  4
# 45  5
# 1   6
# 2   7

# %%
df.iloc[:5]
# Out:
#     0
# 49  1
# 48  2
# 47  3
# 46  4
# 45  5
