# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

iris=pd.read_csv('C:/Users/Suhit/Desktop/ML/ML course Applied/examples/iris.csv')
iris
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
#how many data-point and features?
print(iris.shape)
# Out:
# (150, 5)

# %%
#what are the common names in our dataset?
print(iris.columns)
# Out:
# Index(['sepal.length', 'sepal.width', 'petal.length', 'petal.width',
#        'variety'],
#       dtype='object')

# %%
#how many data points for each class are present?
#how many flowers for each species are present?

iris["variety"].value_counts()
#balanced-dataset vs imbalanced datasets
#iris is a imbalanced dataset as the numner of data points for every class is balanced
# Out:
# Setosa        50
# Versicolor    50
# Virginica     50
# Name: variety, dtype: int64

# %% [markdown]
# ## 2-D scatter plot

# %%
#2-D scatter plot:
#always understand the axis: labels and scale.

iris.plot(kind='scatter',x='sepal.length',y='sepal.width');
plt.show()

#cannot make much sense out it.
#what if we color the points by thier class-label/flowet-type.

# %%
#2-D scatter plot with color-coding for each flower type/class.
#here 'sns' corresponds to seaborn.
sns.set_style("whitegrid");
sns.FacetGrid(iris,hue="variety",height=4) \
   .map(plt.scatter,"sepal.length","sepal.width") \
   .add_legend();
plt.show();

# notic that blue points can be easily seperated
# from red and green by drawing a line.
# but red and green data points cannot be easily seperated.
# can we draw multiple 2-D scatter plots for each combination of features?
# how many combinations exist? 4C2=6.

# %% [markdown]
# ## pair plot

# %%
#pairwise scatter plot:pair-plot
#dis-advantages:
#can be used when no. of features are high.
#cannot visualize higher dimensional patterns in 3-D and 4-D
#only posible to view 2D patterns.

plt.close();
sns.set_style("whitegrid");
sns.pairplot(iris,hue="variety",height=3);
plt.show()

#note:the daigonal elements are PDFs for each feature.

# %%
# pair plots are easy to understand if the dimentionality of the data is small i.e if less no. of featurs.

# %% [markdown]
# ## histogram, PDF,CDF

# %%
#what about 1-D scatter plot using just one feature?
#1-D scatter plot of petal length

import numpy as np
iris_setosa=iris.loc[iris["variety"]=="Setosa"];
iris_virginica=iris.loc[iris["variety"]=="Virginica"];
iris_versicolor=iris.loc[iris["variety"]=="Versicolor"];
# print(iris_setosa["petal.length"])
plt.plot(iris_setosa["petal.length"],np.zeros_like(iris_setosa["petal.length"]))
plt.plot(iris_versicolor["petal.length"],np.zeros_like(iris_versicolor["petal.length"]))
plt.plot(iris_virginica["petal.length"],np.zeros_like(iris_virginica["petal.length"]))

plt.show()

# %%
sns.FacetGrid(iris,hue="variety",height=5) \
   .map(sns.distplot,"petal.length") \
   .add_legend();
plt.show();
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
sns.FacetGrid(iris,hue="variety",height=5) \
   .map(sns.distplot,"petal.width") \
   .add_legend();
plt.show();
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
sns.FacetGrid(iris,hue="variety",height=5) \
   .map(sns.distplot,"sepal.length") \
   .add_legend();
plt.show();
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
sns.FacetGrid(iris,hue="variety",height=5) \
   .map(sns.distplot,"sepal.width") \
   .add_legend();
plt.show();
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# ## cumulative distribution function (CDF)

# %%
#need for cumulative distribution function (cdf)
#we can visually see what percentage of versicolor flowers have a petal.length of less than 1.6?
#how to construct a cdf?
#how to read a cdf?

#plot cdf of petal.length

counts,bin_edges=np.histogram(iris_setosa['petal.length'],bins=10,density=True)

pdf=counts/(sum(counts))
print(pdf);
print(bin_edges)

#compute pdf
cdf=np.cumsum(pdf)  
plt.plot(bin_edges[1:],pdf)   #ploting pdf
plt.plot(bin_edges[1:],cdf)   #ploting cdf

plt.show();
# Out:
# [0.02 0.02 0.04 0.14 0.26 0.26 0.14 0.08 0.   0.04]
# [1.   1.09 1.18 1.27 1.36 1.45 1.54 1.63 1.72 1.81 1.9 ]

# %% [markdown]
# - if we target 1.6 at the x-axis,and y-axis gives the probability,then we can say that there are  82%(roughly) of setosa flower that have petal length less than or equal to 1.6.
#
# - i.e @1.6, the cumulative sum 0f all the propabilities, i.e @1.1+@1.2+-----+@1.6= 0.82 is called the CDF

# %%
# plots of CDF of petal_length for various types of flowers.

#misclassification error if you see petal_length only.

#setosa
counts,bin_edges = np.histogram(iris_setosa['petal.length'],bins=10,density=True)
pdf=counts/(sum(counts))
print(pdf);
print(bin_edges)
cdf=np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:],cdf)

#virginica
counts,bin_edges=np.histogram(iris_virginica['petal.length'],bins=10,density=True)
pdf=counts/sum(counts)
print(pdf);
print(bin_edges)
cdf=np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:],cdf)

#versicolor
counts,bin_edges=np.histogram(iris_versicolor['petal.length'],bins=10,density=True)

pdf=counts/(sum(counts))
print(pdf);
print(bin_edges);
cdf=np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:],cdf)

plt.show();
# Out:
# [0.02 0.02 0.04 0.14 0.26 0.26 0.14 0.08 0.   0.04]
# [1.   1.09 1.18 1.27 1.36 1.45 1.54 1.63 1.72 1.81 1.9 ]
# [0.02 0.1  0.24 0.08 0.18 0.16 0.1  0.04 0.02 0.06]
# [4.5  4.74 4.98 5.22 5.46 5.7  5.94 6.18 6.42 6.66 6.9 ]
# [0.02 0.04 0.06 0.04 0.16 0.14 0.12 0.2  0.14 0.08]
# [3.   3.21 3.42 3.63 3.84 4.05 4.26 4.47 4.68 4.89 5.1 ]

# %% [markdown]
# ## mean, variance and standard deviation

# %%
#mean, variance, standard-deviation
print("means:")
print(np.mean(iris_setosa["petal.length"]))

#mean with outlier.
print(np.mean(np.append(iris_setosa["petal.length"],50)));
print(np.mean(iris_virginica["petal.length"]))
print(np.mean(iris_versicolor["petal.length"]))

print("\nstd-dev:");
print(np.std(iris_setosa["petal.length"]))
print(np.std(iris_virginica["petal.length"]))
print(np.std(iris_versicolor["petal.length"]))
# Out:
# means:
# 1.4620000000000002
# 2.4137254901960787
# 5.552
# 4.26
#
# std-dev:
# 0.17191858538273286
# 0.5463478745268441
# 0.4651881339845204

# %% [markdown]
# ## median, percentile, quantile, IQR,MAD

# %%
#median,Quantiles,percentiles,IQR.
print("\nMedians:")
print(np.median(iris_setosa["petal.length"]))
#median with an outlier
print(np.median(np.append(iris_setosa["petal.length"],50)));
print(np.median(iris_virginica["petal.length"]))
print(np.median(iris_versicolor["petal.length"]))

print("\nQuantiles:")
#the 50th position value in the list [from (1-100)] is called median,and the 50th percentile.
#the 10th position value in the list [from(1-100)] is called the 10th percentile.
#the 25th,50th, 75th and 100th position value in the list is called Quantiles
print(np.percentile(iris_setosa["petal.length"],np.arange(0,100,25)))
print(np.percentile(iris_virginica["petal.length"],np.arange(0,100,25)))
print(np.percentile(iris_versicolor["petal.length"],np.arange(0,100,25)))

print("\n90th Percentiles:")
print(np.percentile(iris_setosa["petal.length"],90))
print(np.percentile(iris_virginica["petal.length"],90))
print(np.percentile(iris_versicolor["petal.length"],90))

from statsmodels import robust
print("\nMedian absolute Deviation")
print(robust.mad(iris_setosa["petal.length"]))
print(robust.mad(iris_virginica["petal.length"]))
print(robust.mad(iris_versicolor["petal.length"]))

#IQR(inter quartile range)= 75th percentile - 25th percentile
# Out:
# Medians:
# 1.5
# 1.5
# 5.55
# 4.35
#
# Quantiles:
# [1.    1.4   1.5   1.575]
# [4.5   5.1   5.55  5.875]
# [3.   4.   4.35 4.6 ]
#
# 90th Percentiles:
# 1.7
# 6.31
# 4.8
#
# Median absolute Deviation
# 0.14826022185056031
# 0.6671709983275211
# 0.5189107764769602

# %% [markdown]
# ## boxplot and whiskers

# %%
#box-plot with whiskers: another method of visualizing the 1-D scatter plot
#the concept of median,percentile,quantile.
#how to draw the box in the box-plot?
#how to draw the whiskers:[no standard way] could use min and max or use other
#IQR like idea.

#note: in the plot below, a technique call inter-quartile range is used in whiskers in the plot below donot correspond to the min and max values.

#box-plot can be visualized as a pdf on the side-ways.

sns.boxplot(x='variety',y='petal.length',data=iris)

plt.show();

# %% [markdown]
# ## violin plots

# %%
#a violin plot combines the benefits of the previous two plots and simplifies them

#denser regions of the data are fatter, and sparser ones thinner in a violin plot.

sns.violinplot(x="variety",y="petal.length",data=iris,size=8)
plt.show();

# %% [markdown]
# ## multivariate probability density, contour plot

# %%
#2D density plot,contours-plot
sns.jointplot(x="petal.length",y="petal.width",data=iris_setosa, kind="kde")
